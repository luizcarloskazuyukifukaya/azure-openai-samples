# %% [markdown]
# # OpenAI Parameters

# %% [markdown]
# # Overview
# When making requests to OpenAI models, several parameters can be used to control the behavior and output of the model. \
# Understanding these parameters helps in fine-tuning the responses to meet specific requirements, whether for generating text, answering questions, or any other use case.
#
# For more detailed examples, refer to the official documentation [Azure OpenAI Service](https://learn.microsoft.com/en-us/azure/ai-services/openai/reference)

# %%
import re
import requests
import sys
import os
from openai import AzureOpenAI
import tiktoken
from dotenv import load_dotenv
load_dotenv()

client = AzureOpenAI(
  azure_endpoint = os.getenv("AZURE_OPENAI_ENDPOINT"), 
  api_key=os.getenv("AZURE_OPENAI_KEY"),  
  #api_version="2024-02-15-preview"
  api_version="2024-10-21"
)

CHAT_COMPLETIONS_MODEL = os.getenv('AZURE_OPENAI_DEPLOYMENT_NAME')
SEED = 123

# %% [markdown]
# # Parameter: max_tokens
# **Description**: The maximum number of tokens to generate in the completion. \
# **Default**: 16 \
# **Example**: max_tokens=50
#
# The token count of your prompt plus max_tokens can't exceed the model's context length. \
# Most models have a context length of 2048 tokens (except for the newest models, which support 4096). Please refer to documentation.

# %%
def call_openai_with_max_tokens(max_tokens):
    response = client.chat.completions.create(
          model=CHAT_COMPLETIONS_MODEL,
          messages = [{"role":"system", "content":"Você é um excelente assistente."},
                    {"role":"user","content": "O melhor animal de estimação é"}],
                    max_tokens=max_tokens
    )
    return response.choices[0].message.content

# Generate with different presence_penalty values
penalties = [16, 32, 60, 100]
for penalty in penalties:
    print(f"Max Tokens: {penalty}\n")
    print(call_openai_with_max_tokens(penalty))
    print("\n" + "-"*80 + "\n")
# Out:
# Max Tokens: 16
#
# O melhor animal de estimação é aquele que combina com o estilo de vida,
#
# --------------------------------------------------------------------------------
#
# Max Tokens: 32
#
# O "melhor" animal de estimação varia de pessoa para pessoa, dependendo de estilo de vida, espaço disponível, preferência pessoal e nível de dedicação que você
#
# --------------------------------------------------------------------------------
#
# Max Tokens: 60
#
# O "melhor" animal de estimação pode variar de pessoa para pessoa, dependendo do estilo de vida, preferências e necessidades individuais. Aqui estão alguns fatores a considerar antes de decidir qual é o melhor animal de estimação para você:
#
# ### **1. Cachorros**
# - **Prós**
#
# --------------------------------------------------------------------------------
#
# Max Tokens: 100
#
# O "melhor" animal de estimação depende de vários fatores, incluindo seu estilo de vida, espaço disponível, orçamento, tempo disponível para cuidados, preferências pessoais e até mesmo alergias. Não há uma resposta universal, porque cada pessoa tem necessidades e expectativas diferentes. Aqui estão alguns populares animais de estimação e os motivos pelos quais podem ser ideais para diferentes tipos de pessoas:
#
# ---
#
# ### **Cachorros**
# - **Características:** Fieis, brincalhões e companheiros extremamente le
#
# --------------------------------------------------------------------------------

# %% [markdown]
# # Parameter: temperature
#
# **Description**: Controls the randomness of the output. Lower values make the output more deterministic, while higher values increase randomness. \
# **Value Range**: 0 to 1 \
# **Default Value**: 1 \
# **Example**: temperature=0.7
#
# Higher values means the model will take more risks. \
# Try 0.9 for more creative applications, and 0 (argmax sampling) for ones with a well-defined answer.
#
# ---
# **NOTE**: We generally recommend altering this or top_p but not both.

# %%
def call_openai(num_times, prompt, temperature=0.75, use_seed=False):
    for i in range(num_times):
        if use_seed:
            response = client.chat.completions.create(
                model=CHAT_COMPLETIONS_MODEL,
                messages = [{"role":"system", "content":"Você é um excelente assistente."},
                            {"role":"user","content": prompt}],
                    max_tokens=60,
                    seed=SEED,
                    temperature = temperature
            )
        else:
            response = client.chat.completions.create(
                model=CHAT_COMPLETIONS_MODEL,
                messages = [{"role":"system", "content":"Você é um excelente assistente."},
                            {"role":"user","content": prompt}],
                    max_tokens=60,
                    temperature = temperature
            )
        print(response.choices[0].message.content)

# %%
# Without seed and temperature, the response is different each time
call_openai(10, 'O melhor animal de estimação é')
# Out:
# O melhor animal de estimação depende completamente do estilo de vida, preferências pessoais e necessidades de cada pessoa. Aqui estão alguns fatores a considerar ao escolher um animal de estimação:
#
# ### 1. **Cães** 🐶
#    - **Por que são ótimos**: Compan
# O melhor animal de estimação é aquele que combina com o seu estilo de vida, personalidade, rotina e preferências. Cada pessoa tem suas necessidades e expectativas em relação a um animal de estimação, e diferentes espécies e raças atendem a essas demandas de formas variadas. Aqui estão algumas opções populares
# Não há uma resposta definitiva para qual é o "melhor" animal de estimação, pois isso depende das preferências, estilo de vida e necessidades de cada pessoa. Diferentes animais possuem características únicas que podem se adequar melhor a diferentes tipos de pessoas e famílias. Aqui estão algumas sugestões baseadas
# O "melhor" animal de estimação pode variar muito de pessoa para pessoa, dependendo do estilo de vida, espaço disponível, dedicação e afinidade com diferentes tipos de animais. Cada espécie tem características únicas que podem fazer dela a melhor escolha para determinadas situações. Aqui estão algumas opções populares e o que
# Não existe uma resposta única para qual é o "melhor" animal de estimação, pois isso depende de vários fatores, incluindo seu estilo de vida, espaço disponível, nível de compromisso e preferências pessoais. Cada animal tem características únicas que podem se adequar melhor a diferentes tipos de pessoas. A
# O "melhor" animal de estimação depende muito do estilo de vida, preferências pessoais, e condições de cada pessoa. Aqui estão algumas considerações para diferentes tipos de animais de estimação:
#
# ### **1. Cachorros**
# - **Ideal para:** Pessoas que têm tempo para passear,
# O "melhor" animal de estimação pode variar muito de pessoa para pessoa, dependendo do estilo de vida, preferências, espaço disponível, tempo disponível para cuidados e interação, além de fatores como alergias ou necessidades emocionais. Aqui estão algumas sugestões com base em diferentes perfis:
#
# ###
# O "melhor" animal de estimação pode variar muito dependendo do que você está procurando em um companheiro, do seu estilo de vida, espaço disponível, tempo e dedicação que pode oferecer. Aqui estão algumas considerações para diferentes tipos de animais de estimação:
#
# ### 1. **Cach
# O "melhor" animal de estimação pode variar de pessoa para pessoa, dependendo de sua personalidade, estilo de vida, necessidades e preferências. Cada animal de estimação tem características únicas que podem ser adequadas para diferentes tipos de tutores. Aqui estão alguns exemplos:
#
# ### 1. **
# O "melhor" animal de estimação pode variar muito de pessoa para pessoa, dependendo do estilo de vida, necessidades, espaço disponível, tempo para cuidados e preferência pessoal. Aqui está uma visão geral para ajudar a decidir qual animal pode ser o ideal para você:
#
# ### 1. **Cães

# %%
# Now using a seed and 0 temperature, the response is the much more consisitent
call_openai(10, 'O melhor animal de estimação é', temperature = 0, use_seed=True)
# Out:
# O "melhor" animal de estimação depende muito do estilo de vida, preferências pessoais e necessidades de cada pessoa. Aqui estão alguns fatores a considerar ao escolher um animal de estimação:
#
# ### **1. Cachorros**
# - **Prós:** Leais, companheiros, interativos e
# O "melhor" animal de estimação depende muito do estilo de vida, preferências e necessidades de cada pessoa. Aqui estão algumas considerações para ajudar a decidir:
#
# ### 1. **Cachorros** 🐶
#    - **Prós**: Leais, afetuosos
# O "melhor" animal de estimação depende muito do estilo de vida, preferências e necessidades de cada pessoa. Aqui estão algumas considerações para ajudar a determinar qual pode ser o melhor animal de estimação para você:
#
# ### 1. **Cães**
#    - **Prós**
# O melhor animal de estimação depende muito do estilo de vida, preferências pessoais e necessidades de cada pessoa. Aqui estão algumas considerações para diferentes tipos de animais:
#
# ### **1. Cachorros**
# - **Prós:** Leais, companheiros, interativos e ótimos para quem gosta de
# O "melhor" animal de estimação depende muito do estilo de vida, preferências e necessidades de cada pessoa. Aqui estão algumas considerações para ajudar a determinar qual pode ser o melhor animal de estimação para você:
#
# ### 1. **Cães**
#    - **Prós**
# O melhor animal de estimação depende muito do estilo de vida, preferências pessoais e necessidades de cada pessoa ou família. Aqui estão alguns fatores a considerar ao escolher o melhor animal de estimação para você:
#
# ### **1. Cachorros**
# - **Prós:** Leais, companheiros, inter
# O melhor animal de estimação depende muito do estilo de vida, preferências pessoais e necessidades de cada pessoa. Aqui estão algumas considerações para ajudar a determinar qual pode ser o melhor animal de estimação para você:
#
# ### **1. Cachorros**
# - **Prós:** Leais, companheiros
# O melhor animal de estimação depende muito do estilo de vida, preferências pessoais e necessidades de cada pessoa ou família. Aqui estão alguns fatores a considerar ao escolher o melhor animal de estimação para você:
#
# ### **1. Cachorros**
# - **Prós:** Leais, companheiros, inter
# O "melhor" animal de estimação depende muito do estilo de vida, preferências e necessidades de cada pessoa. Aqui estão algumas considerações para ajudar a determinar qual pode ser o melhor animal de estimação para você:
#
# ### 1. **Cães**
#    - **Prós**
# O melhor animal de estimação depende muito do estilo de vida, preferências pessoais e necessidades de cada pessoa ou família. Aqui estão alguns fatores a considerar ao escolher o "melhor" animal de estimação para você:
#
# ### **1. Cachorros**
# - **Prós:** Leais, compan

# %% [markdown]
# # Parameter: n
# **Description**: Specifies the number of completions to generate for each prompt. \
# **Default Value**: 1 \
# **Example**: n = 3
#
# ---
# **Note**: Because this parameter generates many completions, it can quickly consume your token quota. Use carefully and ensure that you have reasonable settings for max_tokens and stop.

# %%
response = client.chat.completions.create(
        model=CHAT_COMPLETIONS_MODEL,
        messages = [{"role":"system", "content":"Você é um excelente assistente."},
                {"role":"user","content": "O melhor animal de estimação é"}],
                max_tokens=60,
                n=2
        )

for index, c in enumerate(response.choices):
    print(index, c.message.content)
# Out:
# 0 O "melhor" animal de estimação depende inteiramente das preferências, estilo de vida e necessidades de cada pessoa ou família. Diferentes animais têm personalidades, rotinas e requisitos de cuidados únicos. Aqui estão algumas opções populares e suas características:
#
# ### **Cães**
# - **Por que
# 1 O melhor animal de estimação depende das preferências, estilo de vida e necessidades de cada pessoa ou família. Não existe um "melhor" universal, porque diferentes animais atendem a diferentes desejos e condições. Aqui estão algumas opções comuns para ajudar você a decidir:
#
# ### 1. **Cach

# %% [markdown]
# # Parameter: presence_penalty
# **Description**: Penalizes new tokens based on whether they appear in the text so far, encouraging the model to use new tokens. \
# **Value Range**: -2.0 to 2.0 \
# **Default Value**: 0 \
# **Example**: presence_penalty=0.5

# %%
def call_openai_with_presence_penalty(presence_penalty):
    response = client.chat.completions.create(
        model=CHAT_COMPLETIONS_MODEL,
        messages = [{"role":"system", "content":"Você é um excelente assistente."},
            {"role":"user","content": "O melhor animal de estimação é"}],
            max_tokens=60,
            presence_penalty=presence_penalty
    )
    return response.choices[0].message.content

# Generate with different presence_penalty values
penalties = [0, 0.5, 1.0, 1.5, 2.0]
for penalty in penalties:
    print(f"Presence Penalty: {penalty}\n")
    print(call_openai_with_presence_penalty(penalty))
    print("\n" + "-"*80 + "\n")
# Out:
# Presence Penalty: 0
#
# Choosing the best pet depends on your lifestyle, preferences, and needs. Here are a few options based on different criteria:
#
# 1. **Dogs**: Great for companionship and active lifestyles. They're loyal and require regular exercise.
# 2. **Cats**: More independent than dogs, usually require less maintenance,
#
# --------------------------------------------------------------------------------
#
# Presence Penalty: 0.5
#
# The best pet can vary depending on an individual's lifestyle, preferences, and needs. Here are a few considerations for different types of pets:
#
# 1. **Dogs:** Great companions, highly social, and vary widely in size, temperament, and activity level. Ideal for those who enjoy outdoor activities and have time
#
# --------------------------------------------------------------------------------
#
# Presence Penalty: 1.0
#
# The "best" pet depends on various factors, including your lifestyle, living situation, and personal preferences. Different animals can make great pets for different people:
#
# 1. **Dogs** - Known for their loyalty and companionship, they're great if you have time for daily walks and playtime.
#
# 2.
#
# --------------------------------------------------------------------------------
#
# Presence Penalty: 1.5
#
# The best pet really depends on your personal preferences, lifestyle, and what you're looking for in a companion. Here are some common choices:
#
# - **Dogs**: Known for their loyalty and companionship. They require regular exercise and attention.
#
# - **Cats**: Independent but can be very affectionate. They tend
#
# --------------------------------------------------------------------------------
#
# Presence Penalty: 2.0
#
# The best pet can vary greatly depending on individual circumstances and preferences. Here are a few factors to consider when determining the best pet for you:
#
# 1. **Lifestyle:** If you have a busy lifestyle, a low-maintenance pet like fish or a reptile might be suitable. For those who enjoy physical
#
# --------------------------------------------------------------------------------

# %% [markdown]
# # Parameter: frequency_penalty
# **Description**: Penalizes new tokens based on their existing frequency in the text so far, reducing the likelihood of repeating the same line verbatim. \
# **Value Range**: -2.0 to 2.0 \
# **Default Value**: 0 \
# **Example**: frequency_penalty=0.5

# %% [markdown]
# #### Use cases to explore
# 1. **Compare Responses** \
# Generate multiple completions to compare and choose the best response for your use case.
#
# 2. **Increase Diversity** \
# Use multiple completions to get a variety of responses, which is useful in creative applications.
#
# 3. **Enhance Robustness** \
# Generate multiple responses to ensure consistency and accuracy across different completions.
#
# #### Best Practices
# 1. **Optimize Prompt Length** \
# Keep your prompts concise but informative to ensure the model has enough context.
#
# 2. **Adjust Temperature and Top_p** \
# Use these parameters to balance between deterministic and creative responses.
#
# 3. **Monitor Token Usage** \
# Be mindful of the max_tokens parameter to manage costs and response length.
#
# 4. **Use Stopping Sequences** \
# Define stopping sequences to control where the model should stop generating text, ensuring the output is within the desired context.
#
# 5. **Generate Multiple Completions** \
# Use the n parameter to generate multiple completions and select the best one for your needs.
